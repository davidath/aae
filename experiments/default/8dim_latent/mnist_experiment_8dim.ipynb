# %% [markdown]
# Reconstruction and Generated digits

# %%
# %run ../../../default/test.py -i ../../../cfg/normal_jupyter.ini
# Out:
# INFO [2017-11-21 13:06:40.329619] Loading data........
# INFO [2017-11-21 13:06:40.917042] DONE........
# INFO [2017-11-21 13:06:40.917618] Dataset shape: (10000, 784)

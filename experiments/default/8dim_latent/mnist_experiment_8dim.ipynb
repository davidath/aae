# %% [markdown]
# Reconstruction and Generated digits

# %%
# %run ../../../default/test.py -i ../../../cfg/normal_jupyter.ini
# Out:
# INFO [2017-11-21 12:30:24.803949] Loading data........
# INFO [2017-11-21 12:30:25.429383] DONE........
# INFO [2017-11-21 12:30:25.430002] Dataset shape: (10000, 784)

# %%
! ../../../default/train.py -i ../../../cfg/default/normal_jupyter.ini | tee MNIST_normal_train_log.txt
# Out:
# Can not use cuDNN on context None: Disabled by dnn.enabled flag
# Mapped name None to device cuda: GeForce GTX 950 (0000:01:00.0)
# INFO [2017-11-20 15:58:45.685789] Loading data........
# INFO [2017-11-20 15:58:49.579630] DONE........
# INFO [2017-11-20 15:58:49.579654] Dataset shape: (60000, 784)
# 100%|#########################################| 600/600 [00:06<00:00, 92.06it/s]
# AAE-LRecon [2017-11-20 15:59:01.413570] 0 0.227873
# AAE-LCross [2017-11-20 15:59:01.413630] 0 0.693703
# AAE-LEntr [2017-11-20 15:59:01.413661] 0 0.727475195373
# INFO [2017-11-20 15:59:01.413682] 00:00:06.52
# ...
# 100%|########################################| 600/600 [00:05<00:00, 101.05it/s]
# AAE-LRecon [2017-11-20 15:59:31.586946] 5 0.0702807
# AAE-LCross [2017-11-20 15:59:31.586990] 5 0.693349
# AAE-LEntr [2017-11-20 15:59:31.587044] 5 0.696247782144
# INFO [2017-11-20 15:59:31.587066] 00:00:05.94
# ...
# 100%|#########################################| 600/600 [00:06<00:00, 95.54it/s]
# ...

# %%
# %run ../../../default/test.py -i ../../../cfg/default/normal_jupyter.ini
# Out:
# INFO [2017-11-20 16:11:24.576111] Loading data........
# INFO [2017-11-20 16:11:25.146325] DONE........
# INFO [2017-11-20 16:11:25.148166] Dataset shape: (10000, 784)

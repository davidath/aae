# %%
! ../../../default/train.py -i ../../../cfg/default/swiss_jupyter.ini | tee MNIST_swiss_train_log.txt
# Out:
# Can not use cuDNN on context None: Disabled by dnn.enabled flag
# Mapped name None to device cuda: GeForce GTX 950 (0000:01:00.0)
# INFO [2017-11-20 15:27:25.036034] Loading data........
# INFO [2017-11-20 15:27:28.817455] DONE........
# INFO [2017-11-20 15:27:28.817488] Dataset shape: (60000, 784)
# 100%|########################################| 600/600 [00:05<00:00, 100.94it/s]
# AAE-LRecon [2017-11-20 15:27:39.824009] 0 0.225426
# AAE-LCross [2017-11-20 15:27:39.824057] 0 0.684283
# AAE-LEntr [2017-11-20 15:27:39.824085] 0 0.776375255886
# INFO [2017-11-20 15:27:39.824103] 00:00:05.94
# ...
# 100%|########################################| 600/600 [00:05<00:00, 101.43it/s]
# AAE-LRecon [2017-11-20 15:28:09.472560] 5 0.0712628
# AAE-LCross [2017-11-20 15:28:09.472605] 5 0.674656
# AAE-LEntr [2017-11-20 15:28:09.472650] 5 0.755126422037
# INFO [2017-11-20 15:28:09.472674] 00:00:05.92
# ...
# 100%|########################################| 600/600 [00:05<00:00, 101.89it/s]
# ...

# %%
# %run ../../../default/test.py -i ../../../cfg/default/swiss_jupyter.ini
# Out:
# INFO [2017-11-20 15:54:19.226395] Loading data........
# INFO [2017-11-20 15:54:19.846133] DONE........
# INFO [2017-11-20 15:54:19.846671] Dataset shape: (10000, 784)

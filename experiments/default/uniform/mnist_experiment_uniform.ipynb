# %%
! ../../../default/train.py -i ../../../cfg/default/uniform_jupyter.ini | tee MNIST_uniform_train_log.txt
# Out:
# Can not use cuDNN on context None: Disabled by dnn.enabled flag
# Mapped name None to device cuda: GeForce GTX 950 (0000:01:00.0)
# INFO [2017-11-20 16:14:09.330955] Loading data........
# INFO [2017-11-20 16:14:13.056322] DONE........
# INFO [2017-11-20 16:14:13.056357] Dataset shape: (60000, 784)
# 100%|#########################################| 600/600 [00:06<00:00, 97.65it/s]
# AAE-LRecon [2017-11-20 16:14:24.627481] 0 0.227418
# AAE-LCross [2017-11-20 16:14:24.627545] 0 0.690153
# AAE-LEntr [2017-11-20 16:14:24.627588] 0 0.738002661038
# INFO [2017-11-20 16:14:24.627623] 00:00:06.15
# ...
# 100%|#########################################| 600/600 [00:06<00:00, 99.71it/s]
# AAE-LRecon [2017-11-20 16:14:54.904165] 5 0.0701579
# AAE-LCross [2017-11-20 16:14:54.904232] 5 0.688893
# AAE-LEntr [2017-11-20 16:14:54.904277] 5 0.713715252315
# INFO [2017-11-20 16:14:54.904300] 00:00:06.02
# ...
# 100%|#########################################| 600/600 [00:06<00:00, 98.18it/s]
# ...

# %%
# %run ../../../default/test.py -i ../../../cfg/default/uniform_jupyter.ini
# Out:
# INFO [2017-11-20 16:24:52.776191] Loading data........
# INFO [2017-11-20 16:24:53.353534] DONE........
# INFO [2017-11-20 16:24:53.354172] Dataset shape: (10000, 784)
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.

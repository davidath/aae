# %%
# %run ../../../clustering_paper/train.py -i ../../../cfg/clustering_paper/normal_jupyter.ini
# Out:
# INFO [2017-11-27 13:37:21.310421] Loading data........
# Can not use cuDNN on context None: Disabled by dnn.enabled flag
# Mapped name None to device cuda: GeForce GTX 950 (0000:01:00.0)
# INFO [2017-11-27 13:37:24.962289] DONE........
# INFO [2017-11-27 13:37:24.962908] Dataset shape: (60000, 784)
# INFO [2017-11-27 13:37:24.964263] Plot flag is true, loading test dataset......
# INFO [2017-11-27 13:37:24.964821] Loading data........
# INFO [2017-11-27 13:37:25.550519] DONE........
# INFO [2017-11-27 13:37:25.551228] Dataset shape: (10000, 784)
# 100%|##########| 600/600 [01:05<00:00,  9.19it/s]
# AAE-LRecon [2017-11-27 13:38:46.147702] 0 0.210547
# AAE-Z-Cross [2017-11-27 13:38:46.148263] 0 0.666809
# AAE-Y-Cross [2017-11-27 13:38:46.149626] 0 0.0841083
# AAE-Z-Entr [2017-11-27 13:38:46.150037] 0 0.265052201931
# AAE-Y-Entr [2017-11-27 13:38:46.150471] 0 0.0816209
# INFO [2017-11-27 13:38:46.150881] 00:01:05.31
#  26%|##5       | 154/600 [00:16<00:49,  9.10it/s]

# %%
# %run ../../../clustering_paper/train.py -i ../../../cfg/clustering_paper/normal_jupyter.ini
# Out:
# INFO [2017-11-27 16:15:37.469897] Loading data........
# Can not use cuDNN on context None: Disabled by dnn.enabled flag
# Mapped name None to device cuda: GeForce GTX 950 (0000:01:00.0)
# INFO [2017-11-27 16:15:40.896223] DONE........
# INFO [2017-11-27 16:15:40.896749] Dataset shape: (60000, 784)
# INFO [2017-11-27 16:15:40.898001] Plot flag is true, loading test dataset......
# INFO [2017-11-27 16:15:40.898607] Loading data........
# INFO [2017-11-27 16:15:41.471496] DONE........
# INFO [2017-11-27 16:15:41.472069] Dataset shape: (10000, 784)
# 100%|##########| 600/600 [00:12<00:00, 48.74it/s]
# AAE-LRecon [2017-11-27 16:16:08.060454] 0 0.102892
# AAE-Z-Cross [2017-11-27 16:16:08.061043] 0 0.693474
# AAE-Y-Cross [2017-11-27 16:16:08.061534] 0 0.645698
# AAE-Z-Entr [2017-11-27 16:16:08.062008] 0 0.693754432934
# AAE-Y-Entr [2017-11-27 16:16:08.062512] 0 0.757514
# INFO [2017-11-27 16:16:08.062969] 00:00:12.31
# ...
# 100%|##########| 600/600 [00:12<00:00, 48.26it/s]
# ...

# %%
# %run ../../../clustering/test.py -i ../../../cfg/clustering/normal_jupyter.ini
# Out:
# INFO [2017-11-28 13:08:03.829556] Loading data........
# INFO [2017-11-28 13:08:04.396471] DONE........
# INFO [2017-11-28 13:08:04.397036] Dataset shape: (10000, 784)
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.

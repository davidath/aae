# %%
# %matplotlib inline

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { height:100%;width:100% !important; }</style>"))

# %run ../default_model/./train.py -i ../cfg/aae_default.ini
# Out:
# <style>.container { height:100%;width:100% !important; }</style>
# INFO [2017-11-17 16:23:59.198811] Loading data........
# INFO [2017-11-17 16:24:03.091237] DONE........
# INFO [2017-11-17 16:24:03.091921] Dataset shape: (60000, 784)
# 100%|##########| 600/600 [00:05<00:00, 104.68it/s]
# AAE-LRecon [2017-11-17 16:24:10.960886] 0 0.227985
# AAE-LCross [2017-11-17 16:24:10.961483] 0 0.694631
# AAE-LEntr [2017-11-17 16:24:10.961968] 0 0.719759358459
# INFO [2017-11-17 16:24:10.962392] 00:00:05.73
# ...
# 100%|##########| 600/600 [00:05<00:00, 104.53it/s]
# AAE-LRecon [2017-11-17 16:25:08.961399] 10 0.0642159
# AAE-LCross [2017-11-17 16:25:08.962013] 10 0.693027
# AAE-LEntr [2017-11-17 16:25:08.962484] 10 0.693624764933
# INFO [2017-11-17 16:25:08.962907] 00:00:05.74
# ...
# 100%|##########| 600/600 [00:05<00:00, 101.22it/s]
# AAE-LRecon [2017-11-17 16:26:07.092307] 20 0.0586955
# AAE-LCross [2017-11-17 16:26:07.092867] 20 0.693098
# AAE-LEntr [2017-11-17 16:26:07.093332] 20 0.69326686007
# ...
